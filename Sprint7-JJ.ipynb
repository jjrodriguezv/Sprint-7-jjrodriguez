# %%
import pandas as pd
import matplotlib
#print(matplotlib.__version__)
data_frame = pd.read_csv('C:/Users/User/Documents/CURSO INTRODUCCIO AL BIG DATA I PHYTON/iris.csv')
# data_frame.loc[[0,1,6], ['Sepal.Length']]
# data_frame.describe()
#import LinearRegression
#data_frame.head(10)
import matplotlib.pyplot as plt
plt.plot([2.5,3.8,4.8,5.2],[1, 2, 3, 4])
plt.ylabel('números')
plt.show()

# %% [markdown]
# NIVELL 1
#
# - Exercici 1
# Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades. Pots obtenir més informació del seu càlcul en:
#
# -> Índice de masa corporal IMC que es y como se calcula.
#
# La funció ha de classificar el resultat en les seves respectives categories

# %%
# CALCULADORA DE INDICE DE MASA CORPORAL
def valida_numero (valor):
    try: 
        float(valor)
        return True
    except (ValueError, TypeError):
        return False

def calcula_imc (p,a):
    imc = p/a**2
    return imc

def resultado_imc(imc_calculado):
    if imc_calculado >= 16 and imc_calculado <= 16.9:
        resultado = "su imc indica Delgadez Severa"
    elif imc_calculado >= 17 and imc_calculado <= 18.4:
        resultado = "su imc indica Delgadez Leve"
    elif imc_calculado >= 18.5 and imc_calculado <= 24.9:
        resultado = "su imc indica Peso Normal"
    else:
        resultado = "su imc indica cierto grado de obesidad, debe revisarlo"
    
    return resultado

# Programa Principal
continuar = 1
while continuar == 1:
    peso = int(input("Indique su peso: "))
    es_numero = valida_numero(peso)
    if es_numero == True:
        altura = float(input("Indique altura: (favor utilice . como separador de decimales) "))
        es_numero = valida_numero(altura)
        if es_numero == True:
            if altura <= 2.80:
                su_imc = calcula_imc(peso, altura)
                print(f"Su IMC es: {su_imc}")
                resultado = resultado_imc(su_imc)
                print (f"Diagnostico : {resultado:.2f}")
            else:
                print(f"el valor: {altura}" "esta fuera de rango")
                continuar = 0
        else:
            print("Altura invalida")
            continuar = 0
    else:
        print("introduzca un valor válido, por favor no introduzca letras u otros caracteres")
        continuar = 0
    
    if continuar == 1:
       continuar = int(input("desea continuar? (1 = SI; 0 = NO)"))

print ("Gracias por participar. Hasta Luego")

# Fin Programa Principal
# Out:
# Su IMC es: 24.61810377477591
# su imc indica Peso Normal
# Gracias por participar. Hasta Luego

# %% [markdown]
# - Exercici 2
# Convertidor de temperatures.
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re). Selecciona almenys 2 conversors, de tal manera que en introduir una temperatura retorni, com a mínim, dues conversions.

# %%
# CONVERTIDOR DE GRADOS CELSIUS A CENTIGRDOS Y VICEVERSA
def convierte_far_a_cel (farh):
    celc = float((farh - 32) * 0.555)
    return celc

def convierte_cel_a_far (celc):
    farh = float((celc * 1.8) + 32)
    return farh

#Programa Principal
continuar = 1
while continuar == 1:
    tipo_conversion = int(input("Convertir de Celsius a Fahrenhit presione: 1 - Fahrenhit a Celsius presione: 2"))
    if tipo_conversion == 1: 
        celsius = float(input("Celsius: "))
        faren = convierte_cel_a_far(celsius)
        print(f"Farhenheit: {faren}")
    elif tipo_conversion == 2:
        farhenheit = float(input("Farenheit: "))
        celsius = convierte_far_a_cel(farhenheit)
        print(f"Celsius: {celsius}")
    else:
        print ("Debe indicar un tipo válido de conversión")

    continuar = int(input("desea continuar? (1 = SI; 0 = NO)"))

print ("Gracias por participar. Hasta Luego")
#Fin Programa Principal

# %% [markdown]
# - Exercici 3
# Comptador de paraules d'un text.
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula.

# %%
# CONTADOR DE PALABRAS DE UN TEXTO
# from collections import Counter

def convierte_texto_a_lista(texto):
    return texto.split()

def cuenta_palabras (lista_texto):
    # Se asigna la lista a la variables palabras y se crea un diccionario vacío llamado palabras
    palabras = lista_texto
    diccionario_palabras = dict()

    # se recorre el diccionario a mediante cada uno de sus elementos clave
    # si la palabra está en el diccionario se incrementa en 1 el número de ocurrencias,
    # de lo contrrio, es la primera vez y se asigna 1 al número de ocurrencias
    for palabra in palabras:
        if palabra in diccionario_palabras:
            diccionario_palabras[palabra] += 1
        else:
            diccionario_palabras[palabra] = 1
    return diccionario_palabras

#Programa Principal
# Se solicita el texto y se convierten todas las palabras a lowercase
texto = input("Introduzca texto a evaluar: ")
texto_min = texto.lower()

# El texto es convertido en lista la cual se ordena. Luego ésta pasará como parámetro a la función de conteo de palabras
nueva_lista = convierte_texto_a_lista(texto_min)
nueva_lista.sort()
# print(nueva_lista)
numero_palabras_introducidas = len(nueva_lista)
print(F"La cantidad de palabras introducidas es: {numero_palabras_introducidas}")
print(f"Al ordenar y contar las veces que aparece cada palabra, el resultado es: \n")

#Se llama a la función  de contar palbras y se imprime el diccionario con cada palabra y las veces en que aparece
resultado = cuenta_palabras(nueva_lista)
for palabra, total_palabra in resultado.items():
    print(f"{palabra} :  {total_palabra}", end = " ")

#Fin Programa Principal

# %% [markdown]
# - Exercici 4
# Diccionari invers.
#
# Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviats les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment.

# %%
def diccionari_invers(diccionario_intro):
    valores_intro = list(diccionario_intro.values())
    lista_duplicados = list()
    if len(valores_intro) != len(set(valores_intro)): #La validación se basa en que la estructura SET no permite duplicados
        print("Existen valores duplicados, todos los valores se colocarán en forma de lista")

    diccionario_invertido = dict()
    for clave, valor in diccionario_intro.items():
        if valor in diccionario_invertido:  # Si el valor ya existe como clave en el nuevo diccionario
            diccionario_invertido[valor].append(clave)  # Agregar la clave a la lista existente
        else:
            diccionario_invertido[valor] = [clave]  # Crear una nueva lista con la clave
    return diccionario_invertido
       
#Programa Principal  

diccionario_original = {"a": 1, "b": 2, "c": 3, "d": 2, "e": 3}
# diccionario_original = {"a": 1, "b": 2, "c": 3}
diccionario_invertido = diccionari_invers(diccionario_original)
print(diccionario_invertido) 

#Fin Programa Principal

# %% [markdown]
# Nivell 2
#
#
# Exercici 1
# Diccionari invers amb duplicats
#
# Continuant amb l'exercici 4 del nivell 1: al client es va oblidar de comentar un detall i resulta que els valors en el diccionari original poden duplicar-se i més, per la qual cosa les claus intercanviades poden tenir duplicats. En aquest cas, en l'exercici anterior imprimies un missatge d'advertiment, ara, els valors del diccionari resultant hauran d'emmagatzemar-se com una llista. Tingues en compte que si és un valor únic no ha de ser una llista.

# %%
# Funcion diccionario_intro
def diccionari_invers(diccionario_intro):
    valores_intro = list(diccionario_intro.values())
    lista_duplicados = list()
    if len(valores_intro) != len(set(valores_intro)):
        print("Existen valores duplicados, estos aparecerán en forma de lista, de lo contrario, no será una lista \n")

    diccionario_invertido = dict()
    for clave, valor in diccionario_intro.items():
        if valor in diccionario_invertido:  
            # Si el valor ya existe como clave, se convierte en lista
            if isinstance(diccionario_invertido[valor], list): #La función isinstance determina si valor es del tipo lista
                diccionario_invertido[valor].append(clave) # dado que ya es una lista se hace el append del elemento
            else:
                diccionario_invertido[valor] = [diccionario_invertido[valor], clave] # se crea el elemnto en el diccionario
        else: #el valor no está duplicado
            diccionario_invertido[valor] = clave  
    
    return diccionario_invertido
# Fin funcion diccionario_intro


#Programa Principal  
# diccionario_original = {"a": 1, "b": 2, "c": 3, "d": 2, "e": 3, "f": 4, "g" : 3}
diccionario_original = {"x": 'apple', "y": 'banana', "z": 'banana'}
# diccionario_original = {"a": 1, "b": 2, "c": 3}
diccionario_invertido = diccionari_invers(diccionario_original)
print(diccionario_invertido)

#Fin Programa Principal
# Out:
# Existen valores duplicados, estos aparecerán en forma de lista, de lo contrario, no será una lista
#
# {'apple': 'x', 'banana': ['y', 'z']}

# %% [markdown]
# Exercici 2
# Conversió de tipus de dades
#
# El client rep una llista de dades i necessita generar dues llistes, la primera on estaran tots els elements que es van poder convertir en flotants i l'altra on estan els elements que no es van poder convertir.
#
# Exemple de la llista que rep el client: [ '1.3', 'one' , '1e10' , 'seven', '3-1/2', ('2',1,1.4,'not-a-number'), [1,2,'3','3.4']]

# %%
def separar_datos(lista_datos):
    lista_flotantes = []
    lista_no_convertibles = []

    def intentar_convertir(elemento):
        """ Esta función intenta convertir un elemento a float. Retorna el valor convertido o None si falla. """
        try:
            return float(elemento)
        except (ValueError, TypeError):  # Captura errores de conversión
            return None

    def procesar_elemento(elemento):
        """ Procesa cada elemento de la lista, incluyendo estructuras anidadas. """
        if isinstance(elemento, (list, tuple)):  # Si es una lista o tupla, procesar cada elemento
            for sub_elemento in elemento:
                procesar_elemento(sub_elemento)
        else:
            resultado = intentar_convertir(elemento)
            if resultado is not None:
                lista_flotantes.append(resultado)
            else:
                lista_no_convertibles.append(elemento)

    # Recorrer la lista principal
    for item in lista_datos:
        procesar_elemento(item)

    return lista_flotantes, lista_no_convertibles

#PROGRAMA PRINCIPAL
# Lista de entrada
datos_cliente = ['1.3', 'one', '1e10', 'seven', '3-1/2', ('2', 1, 1.4, 'not-a-number'), [1, 2, '3', '3.4']]

# Llamar a la función
flotantes, no_convertibles = separar_datos(datos_cliente)

# Imprimir resultados
print("Elementos convertidos a float:", flotantes)
print("Elementos no convertibles:", no_convertibles)

#FIN PROGRAMA PRINCIPAL


''' **Explicación del código:**
1. **Función `intentar_convertir(elemento)`**  
   - Intenta convertir un elemento en `float`. Si falla, devuelve `None`.  
   - Captura errores de conversión (`ValueError` para strings no numéricos y `TypeError` para tipos incompatibles como listas o diccionarios).  

2. **Función `procesar_elemento(elemento)`**  
   - Si el elemento es una lista o tupla, procesa cada uno de sus subelementos.  
   - Si es un valor simple, intenta convertirlo. Si puede, lo agrega a `lista_flotantes`, si no, a `lista_no_convertibles`.  

3. **Iteramos sobre la lista dada por el cliente**, llamando a `procesar_elemento` en cada elemento.

# %%
def separar_elementos_convertibles(lista):
    convertibles = []
    no_convertibles = []

    # Procesar cada elemento de la lista
    for elemento in lista:
        if isinstance(elemento, (list, tuple)):  # Si es una lista o tupla, iterar sobre sus elementos
            for elemento_interno in elemento:
                try:
                    convertibles.append(float(elemento_interno))
                except (ValueError, TypeError):
                    no_convertibles.append(elemento_interno)
        else:
            try:
                convertibles.append(float(elemento))
            except (ValueError, TypeError):
                no_convertibles.append(elemento)

    return convertibles, no_convertibles

# Programa Principal
# Lista de entrada
datos = ['1.3', 'one', '1e10', 'seven', '3-1/2', ('2', 1, 1.4, 'not-a-number'), [1, 2, '3', '3.4']]

# Llamada a la función
convertidos, no_convertidos = separar_elementos_convertibles(datos)

# Resultados
print("Elementos convertidos a float:", convertidos)
print("Elementos no convertibles:", no_convertidos)

# Fin Programa Principal

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
dades = plt.plot(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.setp(dades, color='red', linewidth=2.5)
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
plt.bar(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
# plt.bar(cursos,aprovats, color='red', width=0.5)
plt.bar(cursos,aprovats, color='red', width=0.5, edgecolor='yellow', linewidth= 2.0)
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
plt.barh(cursos,aprovats, color='red', height=0.5, edgecolor='green', linewidth= 2.0)
plt.xlabel('aprovats i aprovades')
plt.ylabel('cursos')
plt.title('Aprovats vs cursos')
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats = [22,25,28,29,31]
dades = plt.scatter(cursos,aprovats)
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.setp(dades, color='red', linewidth=2.5)
plt.show()

# %%
cursos = ['1415', '1516', '1617', '1718', '1819']
aprovats1 = [22,25,28,29,31]
aprovats2 = [15,20,37,24,30]
aprovats3 = [20,12,22,30,25]
plt.scatter(cursos,aprovats1, color='yellow')
plt.scatter(cursos,aprovats2, color='red')
plt.scatter(cursos,aprovats3, color='green')
plt.xlabel('cursos')
plt.ylabel('aprovats i aprovades')
plt.show()

# %%
file_path = ('C:/Users/User/Documents/CURSO INTRODUCCIO AL BIG DATA I PHYTON/insurance.csv')
insurance_data = pd.read_csv(file_path)
#print(insurance_data.head(10))
insurance_data.describe()
#plt.scatter(insurance_data['bmi'], insurance_data['charges'],)
#plt.xlabel('bmi')
#plt.ylabel('charges')
#plt.show()

# %%
import seaborn as sns
#sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
#sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
#sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
#sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)
#sns.lmplot(x="bmi", y="charges", hue="children", data=insurance_data)
#sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['charges'])
#sns.swarmplot(x=insurance_data['region'], y=insurance_data['charges'])
#sns.swarmplot(x=insurance_data['region'],y=insurance_data['charges'], hue=insurance_data['smoker'])

# %% [markdown]
# Genera un histograma per a la variable edats (age) i la variable cost (charge).
# Fes un gràfic de dispersió del cost (charges) davant de bmi i diferencia els punts obtinguts, depenent, primer, de si la persona és fumadora o no i, després, de si és de sexe masculí o femení.
# Crea un gràfic de dispersió dels valors bmi en relació, primer, amb el nombre de fills o filles (children) i, després, amb el sexe i, finalment, amb si fuma o no. Tingues present que hi ha una funció específica per crear gràfics de dispersió en els quals una variable és categòrica. El nombre de fills o filles, el sexe i si fuma o no ho són.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
file_path = ('C:/Users/User/Documents/CURSO INTRODUCCIO AL BIG DATA I PHYTON/insurance.csv')
insurance_data = pd.read_csv(file_path)
#insurance_data['age'].hist()
#insurance_data['charges'].hist()
#sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'], hue=insurance_data['sex'])
#sns.lmplot(x="bmi", y="charges", hue="sex", data=insurance_data)
#sns.swarmplot(x=insurance_data['children'],y=insurance_data['bmi'])
#sns.swarmplot(x=insurance_data['sex'], y=insurance_data['bmi'])
sns.swarmplot(x=insurance_data['smoker'],y=insurance_data['bmi'])
#plt.bar(insurance_data['age'],insurance_data['charges'],)
#plt.xlabel('age,charges)
#plt.xlabel('Edad')
#plt.ylabel('Precio')
#plt.bar(age,charges, color='red', width=0.5)
# plt.bar(cursos,aprovats, color='red', width=0.5, edgecolor='yellow', linewidth= 2.0)
#plt.show()

# %% [markdown]
# CREAR, LLEGIR I ESCRIURE BASES DE DADES

# %%
import pandas as pd
fruites = pd.DataFrame([[30,20]], columns=['Pomes', 'Maduixes'])
fruites

fruites_compradors=pd.DataFrame([[30,20],[28,14]],index=['Miquel','Julia'],columns=['Pomes', 'Maduixes'])
fruites_compradors

fruites_compradors_2 = pd.DataFrame({'Pomes':[30,28],'Maduixes':[20,14]}, index=['Miquel','Julia'])
fruites_compradors_2

print(fruites_compradors_2 is fruites_compradors)

fruites_compradors = fruites_compradors_2
print(fruites_compradors_2 is fruites_compradors)

fruites_compradors['Pomes'][0] =15

print(fruites_compradors['Pomes'][0])
print(fruites_compradors_2['Pomes'][0])

# %% [markdown]
# INDEXAR, SELECCIONAR I FILTRAR

# %%
import pandas as pd
data_base = pd.read_csv('C:/Users/User/Documents/CURSO INTRODUCCIO AL BIG DATA I PHYTON/insurance.csv')
#data_base.head()

pd.set_option("display.max_rows", 10)
#data_base

#data_base['region']
#data_base['age']

#data_base['bmi'].max() 
# es similar a hacer: 53.13 es el resultado en ambos casos
#data_base.describe()

# icom ho podem fer per seleccionar només els 30 primers valors d’una columna? Doncs així:
#bmi_30 = data_base['bmi'][0:30]
#bmi_30
#bmi_30.max() 

#data_base_2 = data_base.iloc[0:10,0:2]
#data_base_2

data_base_3 = data_base.iloc[[0,5,6],[0,4]]
data_base_3
